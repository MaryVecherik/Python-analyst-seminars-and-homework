# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('kc_house_data.csv', sep=',')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180  \
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement
# 0      5650     1.0           0     0  ...      7        1180              0  \
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# # Задача 1.
# ### 1.1 Изучите стоимости недвижимости
# Постройте график\
# Назовите график\
# Сделайте именование оси x и оси y\
# Сделайте выводы

# %%
plt.figure(figsize=(8, 6))

plt.hist(df['price'], bins=30)

plt.title('Распределение по стоимости недвижимости')
plt.xlabel('Стоимость')
plt.ylabel('Кол-во домов');

# %% [markdown]
# ### 1.2 Изучите распределение квадратуры жилой
# Постройте график\
# Назовите график\
# Сделайте именование оси x и оси y\
# Сделайте выводы

# %%
plt.figure(figsize=(8, 6))

plt.hist(df['sqft_living'], bins=30)

plt.title('Распределение по жилой площади')
plt.xlabel('Площадь')
plt.ylabel('Кол-во домов');

# %% [markdown]
# ### 1.3 Изучите распределение года постройки
# Постройте график\
# Назовите график\
# Сделайте именование оси x и оси y\
# Сделайте выводы

# %%
plt.figure(figsize=(8, 6))

plt.hist(df['yr_built'], bins=30)

plt.title('Распределение по году постройки')
plt.xlabel('Год постройки')
plt.ylabel('Кол-во домов');

# %% [markdown]
# # Задача 2.
# ### 2.1 Изучите распределение домов от наличия вида на набережную
# Постройте график\
# Сделайте выводы

# %%
plt.figure(figsize=(6, 4))

memory = df['waterfront'].value_counts()
values = memory.values

plt.pie(values, autopct='%1.1f%%', labels=['Есть вид', 'Нет вида'])
plt.title('Распределение домов от наличия вида на набережную');

# %% [markdown]
# ### 2.2 Изучите распределение этажей домов
# Постройте график\
# Сделайте выводы

# %%
expl = [0.2, 0.03, 0.45, 0.05, 0.60, 0.07, 0.88, 0.09, 0.99]

plt.figure(figsize=(8, 6))

memory = df['floors'].value_counts()
names = memory.index
values = memory.values

plt.pie(values, autopct='%1.1f%%', labels=names)
plt.title('Кол-во этажей');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 9
#       6 names = memory.index
#       7 values = memory.values
# ----> 9 plt.pie(values, autopct='%1.1f%%', labels=names, explode=expl)
#      10 plt.title('Кол-во этажей');
#
# File c:\Python 3.11\Lib\site-packages\matplotlib\pyplot.py:2735, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2728 @_copy_docstring_and_deprecators(Axes.pie)
#    2729 def pie(
#    2730         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2733         textprops=None, center=(0, 0), frame=False,
#    2734         rotatelabels=False, *, normalize=True, data=None):
# -> 2735     return gca().pie(
#    2736         x, explode=explode, labels=labels, colors=colors,
# ...

# %% [markdown]
# ### 2.2 Изучите распределение состояния домов
# Постройте график\
# Сделайте выводы

# %%
plt.figure(figsize=(8, 6))

memory = df['floors'].value_counts()
names = memory.index
values = memory.values

plt.pie(values, autopct='%1.1f%%', labels=names)
plt.title('');

# %% [markdown]
# # Задача 3.
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.
